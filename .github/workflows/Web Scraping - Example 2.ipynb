# %%
from bs4 import BeautifulSoup
import requests

job_no = 0

while True:
    url = "https://boston.craigslist.org/search/sof"
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data, 'html.parser')
    jobs = soup.find_all('div', {'class':'result-info'})
    for job in jobs:
        title = job.find('a', {'class':'result-title'}).text
        location_tag = job.find('span', {'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else 'N/A'
        date = job.find('time', {'class':'result-date'}).text
        link = job.find('a', {'class':'result-title'}).get('href')
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_decription = job_soup.find('section', {'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p', {'class', 'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else 'N/A'
        job_no+=1 
        print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link, '\nJob Description:', job_decription, '\nJob Attributes', job_attributes,  '\n-----')
    nextpageurl_tag = soup.find('a', {'title':'next page'})
    if nextpageurl_tag.get('href'):
        url = 'https://boston.craigslist.org' + nextpageurl_tag.get('href')
        print(url)
    else:
        break
        
print('Total Jobs:',job_no)
# Out:
# Job Title: Senior Software Engineer | $120,000 - $180,000 per year
# Location: N/A
# Date: Oct 27
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-engineer-per-year/7221175247.html
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# HireArt is helping Brio Systems hire a skilled and motivated Software Engineer. As a growing startup dedicated to biotechnology and wellness, Brio’s current efforts are focused on enabling access to COVID-19 testing.This position can be performed remotely from anywhere in the U.S. The ability to accommodate typical Eastern Standard Time working hours is required. Brio aims to empower employers to test their teams proactively and on their terms, and gain the insights they need to understand and slow on-site outbreaks, keep employees safe, and manage risk as part of their return-to-work strategies.This is a rare opportunity to get involved in solving a truly meaningful problem with massive scale. The product is up and running, and there is still a ton of room to make your mark as an early member of the team.We’re seeking a Software Engineer who gets excited about challenges, fast-changing environments, and problems with no clear solution. You like to run a disciplined process, but you don’t let it stifle you. You are intuitive but love and respect data. You are opinionated, but equally open to the opinions of others. As Software Engineer, you will:
# Be comfortable across the stack from DevOps to back-end and front-end code, with a passion and strength in at least one zone.
# Follow right-sized processes for development, QC, and release, and be an advocate for evolving them as the company grows.
# Keep the data of users and partners safe through secure code, secure infrastructure, and secure processes.
# Work with the team to define and achieve delivery schedules.
# Contribute to technical specs and plans.
# Work across the board with product designers, sales, and others to deliver the best possible experience to our customers.
# Make a big impact in the company, and on the world.
# The current stack:
# Python 3, Flask, PostgreSQL, and Redis, running on AWS.
# Server-rendered HTML via Jinja, with Javascript and PostCSS, moving towards React.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# Requirements
#
# 3+ years of experience with web-technology coding on a deployed commercial software product
# Demonstrated history of increasing responsibility on the teams and projects you’ve contributed to
# Ability to work in a high-stakes environment where results are critical
# Live experience with back-end development, architecture, and deployment and/or front-end design methodologies and frameworks
# Understanding of creating secure API interfaces, ACL’s, etc.
# Significant, demonstrable experience with current tech stack frameworks and technologies - AWS, Python, PostgreSQL, JavaScript
# Additional qualifications:
# Experience with Microservices
# Experience working on remote teams
# Experience in high-criticality and high-stakes industries like health, finance, aerospace
# Experience working in a seed-stage, high growth startup environment
# Passion for or working knowledge of health, wellness or biology-related topics
# Commitment: This is a full-time (40+ hours per week), contract-to-hire position staffed via HireArt and based in Boston, MA. This position can be performed remotely from anywhere in the U.S. The ability to accommodate typical Eastern Standard Time working hours is required. HireArt values diversity and is an Equal Opportunity Employer. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# About Brio
# BRIO was created to empower individuals with a science-based platform to better understand their health. Founded in 2017, we have developed relationships with labs, medical providers, and employers - all parties who can work together to broaden access to COVID-19 testing. Our expertise puts us in a unique position to help expand testing access through employers, and we have focused all of our company efforts to work on this problem. Crunchbase recently listed us as a ‘Startup to Watch’ and we’re always proud to be picked up by our local tech journalists. We’re currently fully remote, with a center of gravity around Boston, MA where we were founded.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# Job Attributes
# compensation: $120,000 - $180,000 per year
#
# employment type: full-time
#
# telecommuting ok
#
#
# -----
# Job Title: Robotics UX Developer
# Location: Cambridge, MA
# Date: Oct 26
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-robotics-ux-developer/7220439247.html
# Job Description:
#
# QR Code Link to This Post
#
#
# Robotics UX Developer needed in Cambridge, MA-work with Human-Robot Interaction, design/test robots, use C++ or Python. Send resume to headquarters: Toyota Research Institute (Attn: John Wong), 4440 El Camino Real, Los Altos, CA 94022
# Job Attributes
# compensation: please speak to HR regarding compensation
#
# employment type: full-time
#
#
# -----
# Job Title: Archive Developer
# Location: Cambridge, MA
# Date: Oct 23
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-archive-developer/7219173799.html
# Job Description:
#
# QR Code Link to This Post
#
#
# Archive Developer (2 positions)
# Chandra X-ray Telescope Data System
#
# Ad Keywords: Software, developer, programmer, software engineer, archive, database, astronomy, NASA, Chandra, CfA
#
# This is an opportunity with the Data Systems division of the Chandra X-ray Center, which is part of the High Energy Astrophysics Division of the Smithsonian Astrophysical Observatory in Cambridge MA. One of NASA’s Earth-orbiting Great Observatories, the Chandra X-ray telescope has been observing for over 20 years and continues to have a positive impact on the scientific understanding of the universe. We seek two Software Developers for the archive group to contribute to the continued success of the mission.
#
# Join the Chandra X-ray Center and become part of the team working to extend and maintain the Chandra Data archive functionality and to support its operations. The archive contains terabytes of data from the Chandra mission, ensures their integrity, security, and uninterrupted access, and provides interfaces for archiving and retrieval to Science Center Operations and Chandra Science users.
#
# Duties include:
# *  Communicating with scientists and operations teams for software requirements
# * Developing and maintaining software through all phases of the software development lifecycle
# * Documenting software for CXC operations staff and scientific users worldwide
# * Release deployment, server and data migrations, and data archive monitoring
# * Problem analysis and evaluation in support of archive operations and scientific user input
# * Work as part of a team
#
# Knowledge required for the position includes:
# * Proficiency in C++ and Java
# * Experience in SQL/rDBMS
# * Familiarity with relational database servers, web, and JEE application servers in a Unix environment
# * Experience in scripting languages (e.g., Python, Perl) are beneficial since parts of the system include code written in these languages
#
# We offer a challenging and fulfilling working environment in partnership with scientists, operations staff, and an existing software development group, to bring Chandra data to the astronomical community at large.
#
# Benefits include health and dental insurance, vacation and sick time, an institution contributed retirement plan, a flexible spending account, and several insurance opportunities that are all described at the USAJobs link below or on request from the contact person identified on the site.
#
# We accept only on-line applications for this position. For complete information and online application procedures, please visit
#
# https://www.usajobs.gov/GetJob/ViewDetails/578814100
#
# We are an equal employment opportunity employer, committed to diversity in our workplace.
# Job Attributes
# compensation: Competitive
#
# employment type: full-time
#
#
# -----
# Job Title: Become a Web Developer. No Experience Needed (Remote)
# Location: N/A
# Date: Oct 22
# Link: https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7218360312.html
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Boston.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# Job Attributes
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# -----
# Job Title: Software Quality Assurance Engineer
# Location: Cambridge/Remote
# Date: Oct 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-quality-assurance/7218148252.html
# Job Description:
#
# QR Code Link to This Post
#
#
#
#
#
# Software Quality Assurance Engineer at CRIO
#
# Clinical Research IO (CRIO) aims to transform and streamline the process of clinical trials, replacing the traditional paper-based manual workflows with a SAAS solution that improves efficiency and reduces error.  Our business operates at the intersection of healthcare and life-science research.  Our customers include clinical research sites, hospitals, biotech and pharma.  We have developed an enterprise solution for research investigators, and we are embarking on building a platform for biotech and pharma sponsors. We provide value to our customers in this highly regulated industry by capturing data that is clean and accurate, eliminating expensive human intervention, and making research data available in real-time.
#
# We’re looking to expand our team of developers located in our Boston office, and remote!
#
# As part of our agile team, you’ll be working in a startup environment where you’ll have the opportunity to work closely with our customers and product team as we deliver enhancements and build new products in an industry with a mission to improve the quality of human life.
#
# About Us
#
# We are a small, fast-growing startup company with a strong team of developers, a loyal customer base, and a highly regarded brand.  Our company culture emphasizes trust, teamwork, collaboration, learning, career growth, and fun!  In our streamlined startup environment, nobody is just a developer.  Each of us wears many hats, gets to know our customers and business, and has opportunities to contribute broadly to the company mission.  Our people are our most important asset, and we build our team carefully to maintain the values of our culture.
#
# About You
#
# You are an experienced and dedicated Quality Assurance Engineer with strong testing fundamentals, who understands QA methodologies, software development lifecycle, as well as issue tracking & resolution, and has contributed to test automation.  You are committed to best practices, and you take personal ownership of the quality of your product.  You enjoy collaboration, and thrive in a team environment where everyone is working towards a common goal.  You enjoy getting to know your team on a personal level, and you love finding ways to have fun while doing your job!
#
# Responsibilities
#
# -Functional and backend testing of new features on a fast paced release cycle and regression testing leading towards a smooth release to production.
# -Performing regression and integration testing for all stages (Dev/QA/UAT/Prod) of SDLC
# -Creating and executing test scripts, test scenarios, and maintenance of test plans.
# -Collaborating with the development/product teams and follow-up with them regarding bugs/resolution ensuring quality of the product.
# -Performing backend testing by working with databases/SQL queries.
#
# Technical Skills
#
# -5+ years of prior software testing experience.
# -Strong knowledge of QA Methodologies and Software Development Life Cycle (SDLC).
# -Ability to understand business requirements and translate them into test plans and scripts.
# -Expertise with Acceptance/Regression/Functional testing skills.
# -Familiarity with issue tracking tools like JIRA, part of Agile process and Scrum.
# -Strong database testing skills including writing SQL scripts and queries using joins, analyzing/debugging data from tables with an understanding of how tables are related from the business perspective.
# -Experience with writing test automation and with related scripting and programming  languages.
# -Experience writing and executing automated test plans, scenarios and scripts.
# -Demonstrated ability to investigate, analyze, and debug test failures to ensure actionable reporting.
# -Experience working in an Agile development environment is a plus.
# -Analyze data to perform assessment of current quality of the product.
# -Degree in Computer Science/Applications or Mathematics or similar field is preferred.
#
# Leadership Skills
#
# -Ability to lead while contributing as part of a collaborative agile team
# -Excellent written and verbal communication skills
# -Ability to work with developers/product teams, and co-ordinate testing efforts towards smooth release of product.
# -Ability to influence team, stakeholders, and leadership as needed
# -Strong focus on team effectiveness, results and customer success
# -Self-motivated and proactive in terms of identifying and resolving problems
# -Passionate about technology and staying current with industry trends
# -Natural tendency towards continuous improvement for self and team
# -Quick learner, self starter, proven experience to take ownership and work independently.
#
# Location
# Boston, MA (and remote)
#
#
#
#
#
# The Berkner Group has been retained to execute this search. If you were contacted by The Berkner Group, please reply to the person who contacted you. If you are applying to a job posting, please include your name and the title for this position (“[Your name] — CRIO -   Software Quality Assurance Engineer”) in the subject line of your email.
# We look forward to hearing from you!
#
#
#
#
#
# Job Attributes
# compensation: Competitive base plus benefits
#
# employment type: full-time
#
#
# -----
# Job Title: Software Engineer, Automated Mapping | Toyota
# Location: Cambridge
# Date: Oct 21
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7217902816.html
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# HireArt is helping TRI hire a skilled and highly motivated Software Engineer to support the development and performance of high-definition maps for autonomous driving. This position is fully remote and has potential for extension for the right candidate. Applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. In an era of increasing vehicle automation, having up-to-date and highly accurate maps is critical to ensuring safe vehicle operation both on the highway and on surface roads. As Software Engineer, Mapping, you’ll have the opportunity to work with engineers and researchers innovating in autonomous mapping and driving technology. The ideal candidate is an adept engineer experienced in Linux, Git, and C++. You're also a great communicator, collaborator, and problem-solver. As Software Engineer, Mapping you will:
# Collaborate with other software engineers and research scientists to improve the software behind maintaining high-definition maps for autonomous driving.
# Be at the front-line interfaces between engineers, researchers, and map annotators to decrease turn-around time for map updates and feature requests.
# With the guidance of senior software engineers, implement high-quality software to allow for both high-performance and easily understandable and maintainable software.
# Live and breathe the software practices that produce maintainable code, including automated testing, continuous integration, code style conformity, and code review.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# Requirements
#
# B.S. in Computer Science or a related field
# 2+ years of professional experience in related position
# A great team player and collaborator
# Strong communication skills
# Experienced in Linux, Git, and C++.
# Experience with 3D graphics/OpenGL preferred
# Ability to work with Python code as needed
# Commitment: This is a full-time (40 hours per week), 6-month contract position with potential for extension. This role is staffed via HireArt and based in Los Altos, CA. This position is fully remote and applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. HireArt provides Equal Employment Opportunity without regard to the applicant's race, color, creed, gender, gender identity or expression, sexual orientation, national origin, age, physical or mental disability, medical condition, religion, marital status, genetic information, veteran status, or any other status protected under federal, state or local laws. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# About Toyota Research Institute
# At Toyota Research Institute (TRI), we’re working to build a future where everyone has the freedom to move, engage, and explore with a focus on reducing vehicle collisions, injuries, and fatalities. Join us in our mission to improve the quality of human life through advances in artificial intelligence, automated driving, robotics and materials science. We’re dedicated to building a world of “mobility for all” where everyone, regardless of age or ability, can live in harmony with technology to enjoy a better life. Through innovations in AI, we’ll...● Develop vehicles incapable of causing a crash, regardless of the actions of the driver.● Develop technology for vehicles and robots to help people enjoy new levels of independence, access, and mobility.● Bring advanced mobility technology to market faster.● Discover new materials that will make drive batteries and hydrogen fuel cells smaller, lighter, less expensive and more powerful.Our work is guided by a dedication to safety – in how we research, develop, and validate the performance of vehicle technology to benefit society. As a subsidiary of Toyota, TRI is fueled by a diverse and inclusive community of people who carry invaluable leadership, experience, and ideas from industry-leading companies. Over half of our technical team carries PhD degrees. We’re continually searching for the world’s best talent ‒ people who are ready to define the new world of mobility with us!We strive to build a company that helps our people thrive, achieve work life balance, and bring their best selves to work. At TRI, you will have the opportunity to enjoy the best of both worlds ‒ a fun start up environment with brilliant people who enjoy solving tough problems and the financial backing to successfully achieve our goals. If you’re passionate about working with smart people to make cars safer, enable the elderly to age in place, or design alternative fuel sources, TRI is the place for you. ‒ Start your impossible with us. https://www.tri.global/
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# Job Attributes
# compensation: Competitive
#
# employment type: full-time
#
# telecommuting ok
#
#
# -----
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Oct 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7217886886.html
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# Job Attributes
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# -----
# Job Title: Director of DevOps
# Location: boston: northwest/merrimack
# Date: Oct 20
# Link: https://boston.craigslist.org/nwb/sof/d/billerica-director-of-devops/7217205659.html
# Job Description:
#
# QR Code Link to This Post
#
#
# Director of DevOpsA SaaS company is looking for a leader with a solid background in operating a global platform using strong skills in agile project management. Leading this team is a pivotal role that influences every aspect of what the company does today and what it can do in the future.Your skillsExperience running a global SaaS operation with AWS, GCP, or Azure.Experience managing, mentoring and building high-performing teamsWell versed in agile methods for delivering software and operational changes.Understanding of configuration management (Ansible, Puppet), container deployment (Docker, Kubernetes, Jira, Confluence etc.ResponsibilitiesLead the team responsible for the operational health of all product servicesOversee and participate in daily activities of the Hosting Operations group responsible for running multiple 24/7/365 SaaS application cloud environments.Work in collaboration with Engineering and Product ManagementEnsure that the Operations team members have the proper resources, skills and tools to accomplish their assigned tasks and objectives.Drive automation efforts to continually increase operational efficiency and quality.Build and monitor systems for automating product releases, data backup, maintenance, internal and external monitoring, environmental analysis, OS and software patching.Manage costs of services, licensing, and hosting environmentsActively pursue and recommend new technologiesIn addition to competitive base salary you'll receive a performance bonus and generous benefits packageFind Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Life Sciences and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# Job Attributes
# compensation: Negotiable
#
# employment type: full-time
#
#
# -----
# Job Title: 100% Remote Based Infrastructure/DevOps Engineer
# Location: boston: boston/cambridge/brookline
# Date: Oct 19
# Link: https://boston.craigslist.org/gbs/sof/d/boston-100-remote-based-infrastructure/7217067547.html
# Job Description:
#
# QR Code Link to This Post
#
#
# DevOps/Infrastructure Engineer  (Boston, MA)compensation: $150KOne of the Boston's fastest growing Data Analytics and Cryptocurrency companies that is building the next frontier of financial trading software seeks to hire a DevOps/Infrastructure Engineer to join its 100% Remote based team. YOUR CAREER GOALSContribute to the mission of changing the way data is shared,  secrured, delivered and managed. Building on your experience, you will also assist in addressing requests and requirements for new infrastructure, and assist developing the infrastructure to support this digital SaaS platform.YOUR AMAZING QUALITIESYou understand the ins and outs of creating a cloud based SaaS platform within a Linux enviornment. You recognize process or programming inefficiencies and can recommend helpful improvements to assist with the user's experience. You have a B.S. degree or higher in Computer Science, Information Technology & Services, Software Engineering, or a related field, and at least three years of professional experience with:AWSPostgreSQLAnsibleDockerTerraformAnd if you've got knowledge or experience in:PythonData Analytics or Machine Learning Nginx...those are certainly pluses!You must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:401(k)Life Insurance PolicyGreat Health BenefitsFind Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Life Sciences and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# Job Attributes
# compensation: $90000 - $150000 per year
#
# employment type: full-time
#
#
# -----
# Job Title: Senior Software Engineer - Python
# Location: boston: boston/cambridge/brookline
# Date: Oct 19
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-engineer-python/7216981824.html
# Job Description:
#
# QR Code Link to This Post
#
#
# Senior Software Engineer - Boston, MA - $160K plus equity  A fast-growing software startup within the fintech industry is currently seeking a Senior Software Engineer. This is an opportunity to partner up with a team of entrepreneurs who have been together for years and are looking to add more great engineers to meet customer demand. This team is looking for a friendly, communicative engineer with solid Python backend engineering skills and a deep understanding of what it takes to build ambitious and innovative professional software from both a code quality and architectural design perspective.  What you will be working on:Modern, developer-driven tech stack: Python/Postgres/Django/AngularDevelop engineering solutions to product requirements and specificationsIntegrate next-generation software within client environments (banking and finance systems)Collaborate with team members to create and extend architectures which will support major new product featuresReview team member's code and recommend improvementsExperience:3+ years of developing major software components in PythonProven ability to independently conceive and develop innovative architectures through to completionWork as a member of a development team delivering complex, modular productsUnderstanding of web application architectures and frameworks, especially MVCSaaS B2B product domain experience is a plusComputer Science or equivalent degree (BS or MS) desired but not requiredWhat's in it for you?Competitive base salary and impressive equity packageFast paced and agile environmentR&D approach to development within an engineering focused firm (70% of the team is made up of software engineers)A proven track record of success - the board and C-level leadership have successfully started and managed software product firms in the pastFlex scheduleUnlimited vacationCasual dress100% Remote option should you prefer remote Health, dental, and 401kFind Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Life Sciences and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# Job Attributes
# compensation: $70000 - $150000 per year
#
# employment type: full-time
#
#
# -----
# Job Title: Senior Software Engineer | $120,000 - $180,000 per year
# Location: N/A
# Date: Oct 19
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-engineer-per-year/7216726341.html
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# HireArt is helping Brio Systems hire a skilled and motivated Software Engineer. As a growing startup dedicated to biotechnology and wellness, Brio’s current efforts are focused on enabling access to COVID-19 testing.This position can be performed remotely from anywhere in the U.S. The ability to accommodate typical Eastern Standard Time working hours is required. Brio aims to empower employers to test their teams proactively and on their terms, and gain the insights they need to understand and slow on-site outbreaks, keep employees safe, and manage risk as part of their return-to-work strategies.This is a rare opportunity to get involved in solving a truly meaningful problem with massive scale. The product is up and running, and there is still a ton of room to make your mark as an early member of the team.We’re seeking a Software Engineer who gets excited about challenges, fast-changing environments, and problems with no clear solution. You like to run a disciplined process, but you don’t let it stifle you. You are intuitive but love and respect data. You are opinionated, but equally open to the opinions of others. As Software Engineer, you will:
# Be comfortable across the stack from DevOps to back-end and front-end code, with a passion and strength in at least one zone.
# Follow right-sized processes for development, QC, and release, and be an advocate for evolving them as the company grows.
# Keep the data of users and partners safe through secure code, secure infrastructure, and secure processes.
# Work with the team to define and achieve delivery schedules.
# Contribute to technical specs and plans.
# Work across the board with product designers, sales, and others to deliver the best possible experience to our customers.
# Make a big impact in the company, and on the world.
# The current stack:
# Python 3, Flask, PostgreSQL, and Redis, running on AWS.
# Server-rendered HTML via Jinja, with Javascript and PostCSS, moving towards React.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# Requirements
#
# 3+ years of experience with web-technology coding on a deployed commercial software product
# Demonstrated history of increasing responsibility on the teams and projects you’ve contributed to
# Ability to work in a high-stakes environment where results are critical
# Live experience with back-end development, architecture, and deployment and/or front-end design methodologies and frameworks
# Understanding of creating secure API interfaces, ACL’s, etc.
# Significant, demonstrable experience with current tech stack frameworks and technologies - AWS, Python, PostgreSQL, JavaScript
# Additional qualifications:
# Experience with Microservices
# Experience working on remote teams
# Experience in high-criticality and high-stakes industries like health, finance, aerospace
# Experience working in a seed-stage, high growth startup environment
# Passion for or working knowledge of health, wellness or biology-related topics
# Commitment: This is a full-time (40+ hours per week), contract-to-hire position staffed via HireArt and based in Boston, MA. This position can be performed remotely from anywhere in the U.S. The ability to accommodate typical Eastern Standard Time working hours is required. HireArt values diversity and is an Equal Opportunity Employer. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# About Brio
# BRIO was created to empower individuals with a science-based platform to better understand their health. Founded in 2017, we have developed relationships with labs, medical providers, and employers - all parties who can work together to broaden access to COVID-19 testing. Our expertise puts us in a unique position to help expand testing access through employers, and we have focused all of our company efforts to work on this problem. Crunchbase recently listed us as a ‘Startup to Watch’ and we’re always proud to be picked up by our local tech journalists. We’re currently fully remote, with a center of gravity around Boston, MA where we were founded.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# Job Attributes
# compensation: $120,000 - $180,000 per year
#
# employment type: full-time
#
# telecommuting ok
#
#
# -----
# Job Title: Software Engineer, Automated Mapping | Toyota
# Location: Cambridge
# Date: Oct 15
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7214467492.html
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# HireArt is helping TRI hire a skilled and highly motivated Software Engineer to support the development and performance of high-definition maps for autonomous driving. This position is fully remote and has potential for extension for the right candidate. Applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. In an era of increasing vehicle automation, having up-to-date and highly accurate maps is critical to ensuring safe vehicle operation both on the highway and on surface roads. As Software Engineer, Mapping, you’ll have the opportunity to work with engineers and researchers innovating in autonomous mapping and driving technology. The ideal candidate is an adept engineer experienced in Linux, Git, and C++. You're also a great communicator, collaborator, and problem-solver. As Software Engineer, Mapping you will:
# Collaborate with other software engineers and research scientists to improve the software behind maintaining high-definition maps for autonomous driving.
# Be at the front-line interfaces between engineers, researchers, and map annotators to decrease turn-around time for map updates and feature requests.
# With the guidance of senior software engineers, implement high-quality software to allow for both high-performance and easily understandable and maintainable software.
# Live and breathe the software practices that produce maintainable code, including automated testing, continuous integration, code style conformity, and code review.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# Requirements
#
# B.S. in Computer Science or a related field
# 2+ years of professional experience in related position
# A great team player and collaborator
# Strong communication skills
# Experienced in Linux, Git, and C++.
# Experience with 3D graphics/OpenGL preferred
# Ability to work with Python code as needed
# Commitment: This is a full-time (40 hours per week), 6-month contract position with potential for extension. This role is staffed via HireArt and based in Los Altos, CA. This position is fully remote and applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. HireArt provides Equal Employment Opportunity without regard to the applicant's race, color, creed, gender, gender identity or expression, sexual orientation, national origin, age, physical or mental disability, medical condition, religion, marital status, genetic information, veteran status, or any other status protected under federal, state or local laws. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# About Toyota Research Institute
# At Toyota Research Institute (TRI), we’re working to build a future where everyone has the freedom to move, engage, and explore with a focus on reducing vehicle collisions, injuries, and fatalities. Join us in our mission to improve the quality of human life through advances in artificial intelligence, automated driving, robotics and materials science. We’re dedicated to building a world of “mobility for all” where everyone, regardless of age or ability, can live in harmony with technology to enjoy a better life. Through innovations in AI, we’ll...● Develop vehicles incapable of causing a crash, regardless of the actions of the driver.● Develop technology for vehicles and robots to help people enjoy new levels of independence, access, and mobility.● Bring advanced mobility technology to market faster.● Discover new materials that will make drive batteries and hydrogen fuel cells smaller, lighter, less expensive and more powerful.Our work is guided by a dedication to safety – in how we research, develop, and validate the performance of vehicle technology to benefit society. As a subsidiary of Toyota, TRI is fueled by a diverse and inclusive community of people who carry invaluable leadership, experience, and ideas from industry-leading companies. Over half of our technical team carries PhD degrees. We’re continually searching for the world’s best talent ‒ people who are ready to define the new world of mobility with us!We strive to build a company that helps our people thrive, achieve work life balance, and bring their best selves to work. At TRI, you will have the opportunity to enjoy the best of both worlds ‒ a fun start up environment with brilliant people who enjoy solving tough problems and the financial backing to successfully achieve our goals. If you’re passionate about working with smart people to make cars safer, enable the elderly to age in place, or design alternative fuel sources, TRI is the place for you. ‒ Start your impossible with us. https://www.tri.global/
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# Job Attributes
# compensation: Competitive
#
# employment type: full-time
#
# telecommuting ok
#
#
# -----
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Oct 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7213844738.html
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# Job Attributes
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# -----
# Job Title: Become a Top Certified AWS Engineer. No IT background required.
# Location: N/A
# Date: Oct 14
# Link: https://boston.craigslist.org/gbs/sof/d/brookline-village-become-top-certified/7213728517.html
# Job Description:
#
# QR Code Link to This Post
#
#
# If you’re looking for an extra edge in landing a new job or promotion, cloud certification can be a great option. A lot of opportunities will open up: you can pursue career paths like AWS Solutions Architect, Cloud Developer, AWS Engineer, Cloud Systems Engineer, DevOps Engineer, Cloud Architect and AWS SysOps Admin among others. AWS training will help you grab this opportunity and accelerate your career.
#
# AWS Certification holds Great Value in today's job market - Now is the Time! Cloud Architects are in great demand worldwide.
#
# Many organizations have moved to cloud platforms for better scalability, mobility, and security, and cloud solutions architects are among the highest paid professionals in the IT industry. According to Forbes, enterprise IT architects with cloud computing expertise are earning a median salary of $137,957.
#
# AWS Certification Training from ZiyoTek Institute of Technology is designed to provide in-depth knowledge about AWS architectural principles and its services. We offer structured AWS training with an updated curriculum as per current industry requirements and best hands-on practices. We have passionate AWS instructors, who not only have real-world experience, but also go through a rigorous process to validate their teaching expertise. The school also offers personalized financial planning options.
#
# Are you ready to Jump-Start Your Career and Increase Your Salary ?
#
# ** Classes Begin on December 1, 2020 **
#
# Would like to learn more about the program? Sign up for free Event hosted by experienced instructors, where you can learn a lot about the program. This session is MANDATORY if you are planning to sign up for an AWS course.
#
# Register here: https://www.eventbrite.com/e/cloud-architect-online-info-session-east-ca013-wi20-tickets-122704834463
#
# Date: Sun, November 8, 2020
# Time: 11 AM - 12:30 PM (EDT)
# Location: Online Webinar
#
# Contact us at ziyotek@ziyotek.com
# Call us at 202-221-8221
# Visit us at ziyotek.com
# Job Attributes
# compensation: 120,000
#
# employment type: employee's choice
#
#
# -----
# Job Title: Software Engineer | $80,000 - $120,000 per year
# Location: N/A
# Date: Oct 13
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-per-year/7213303093.html
# Job Description:
#
# ...
#
# Millions of kids, parents, and teachers visit ABCya.com each month, playing over 1 billion games last year. ABCya's educational games have been featured by Apple, The New York Times, USA Today, Parents Magazine, Scholastic, and other notable publications. ABCya is located in Providence, and our office is accessible by car or bus.
#
#
# WHAT YOU'LL BE DOING
# As a Full-Stack Software Engineer at ABCya, you will assist in maintaining back-end services and databases, build and maintain the GraphQL API, and help build our web clients. You’ll be leading the back-end development effort and assisting with front-end tasks as needed. In addition to working with your fellow engineers, you’ll collaborate with other teams to design amazing products that meet the needs of our users, who are kids, parents, and teachers all over the world.
#
# TECHNOLOGY
#
#
# Our backend stack includes Amazon Web Services, Prisma/ Nexus Prisma, Serverless Framework, MySQL, Netlify, GitLab and Stripe.
#
# The API code is written in GraphQL, JavaScript/Node.js and TypeScript.
#
# The front-end code is written in JavaScript using the React framework.
#
# WHAT WE'RE LOOKING FOR
#
# A solid grasp of general programming principles and backend infrastructure
# Excellent programming skills in JavaScript, Node.js and working knowledge of Typescript
# Experience with Amazon Web Services such as: Lambda, API Gateway, EC2, RDS/ Aurora, S3, IAM, Route 53, Cloudfront, Elasticache/ Redis
# Ability to work both independently and with a wide variety of teams
# Knowledge of GraphQL APIs, serverless applications and Jest unit testing are a plus
# Passion for improving education through technology and games
#
# ABOUT IXL
#
# IXL Learning is a leading educational technology company on a big mission: creating innovative learning experiences that help all learners reach their full potential. IXL's comprehensive curriculum and insightful analytics help more than 500,000 teachers deliver personalized instruction and empower over 10 million students to achieve new learning milestones every day.
#
# At IXL, we’re passionate about our mission of creating the best educational technology that improves learning for all students. We bring that same passion to creating a workplace that values diversity on the basis that all of us bring a unique perspective and experience that advances IXL’s mission.
#
# We strive to increase diversity in race, ethnicity, gender, age, sexual orientation, and physical or mental ability and to continually promote a work environment where everyone, from any background, can do their best work.
# Click here to apply
# Job Attributes
# compensation: Competitive salary and benefits
#
# employment type: full-time
#
#
# -----
# Job Title: TRUCK ROUTER
# Location: N/A
# Date: Oct 22
# Link: https://providence.craigslist.org/sof/d/swansea-truck-router/7218421591.html
# Job Description:
#
# QR Code Link to This Post
#
#
# ##########################################
# Please reply to this posting with your personal or company email AND phone number
# email: Clayton Cardoza        Email:  ccardoza @ nehds . com
# ##########################################
#
#
#
#
#
# Job Status: Full Time / 5 days / Evenings hours / Open Schedule availability / PM Hours: Monday / Tuesday / Wednesday / Friday 2pm-10pm AM Hours Saturday 7:00am – 3:30pm
# Industry: Transportation / Routing
#
#
# Essential Duties and Responsibilities
# Organizes and schedules all necessary resources required to accomplish activities. Coordinates daily operational needs with Leadership team.
# · Plans, distributes,monitors, and follows-up daily route assignments to ensure customers are serviced per Macys Furniture / NEHDS standards and agreements.
# · Monitors driver and laborer time and attendance, minimizing overtime and ensuring that drivers do not exceed limits established by regulatory agencies (e.g., 60 hour rule).
# · Reviews weekly demand/ volume for routes, determines potential gains from re-routing, and recommend-routes to the routing specialist.
# · Sets and monitors productivity, service, and safety targets for each route and driver.
# · Knowledge, Skills or Abilities Required Previous experience working in a routing capacity required.
# · Previous experience support delivery drivers 1-3 years.
# · Previous experience working in the transportation, logistics or home decor strongly preferred.
# · Flexible hours – able to work weekends
#
#
# REQUIREMENTS/SKILLS:
# · Excellent verbal and written communication skills.
# · Computer skills;working knowledge of Windows applications, Microsoft applications.
# · Delivery Routing software (Global Positioning System) 1-3 years.
# · Proven customer service skills.
# · Knowledge of Metro New England area with the ability to read maps.
# · Must be able to work independently, make decisions, and resolve problems.
# · Must have knowledge of DOT/OSHA regulations.
# · Additional skills maybe required to perform additional task(s) specific to work location, department or line of business.
# · Must be able to jockey 26 Ft. box trucks in the depot yard.
#
# QUALIFICATIONS:
# · Current Driver License
# · High school diploma or equivalent.
# · Must successfully complete pre-employment testing / back ground / drug screening.
# · Must be able to read and speak the English language.
# · Must be able to work flexible schedules including weekends and holidays, and be available to address operational issues.
# NEHDS offers competitive compensation and comprehensive benefits package:
# · Health, Dental, life-insurance.
#
# Job Attributes
# compensation: 15.00 - $16.00 per hour
#
# employment type: full-time
#
#
# -----
# Job Title: TRUCK ROUTER
# Location: N/A
# Date: Oct 20
# Link: https://providence.craigslist.org/sof/d/swansea-truck-router/7217604628.html
# Job Description:
#
# QR Code Link to This Post
#
#
# ##########################################
# Please reply to this posting with your personal or company email AND phone number
# email: Clayton Cardoza        Email:  ccardoza @ nehds . com
# ##########################################
#
#
#
#
#
# Job Status: Full Time / 5 days / Evenings hours / Open Schedule availability / PM Hours: Monday / Tuesday / Wednesday / Friday 2pm-10pm AM Hours Saturday 7:00am – 3:30pm
# Industry: Transportation / Routing
#
#
# Essential Duties and Responsibilities
# Organizes and schedules all necessary resources required to accomplish activities. Coordinates daily operational needs with Leadership team.
# · Plans, distributes,monitors, and follows-up daily route assignments to ensure customers are serviced per Macys Furniture / NEHDS standards and agreements.
# · Monitors driver and laborer time and attendance, minimizing overtime and ensuring that drivers do not exceed limits established by regulatory agencies (e.g., 60 hour rule).
# · Reviews weekly demand/ volume for routes, determines potential gains from re-routing, and recommend-routes to the routing specialist.
# · Sets and monitors productivity, service, and safety targets for each route and driver.
# · Knowledge, Skills or Abilities Required Previous experience working in a routing capacity required.
# · Previous experience support delivery drivers 1-3 years.
# · Previous experience working in the transportation, logistics or home decor strongly preferred.
# · Flexible hours – able to work weekends
#
#
# REQUIREMENTS/SKILLS:
# · Excellent verbal and written communication skills.
# · Computer skills;working knowledge of Windows applications, Microsoft applications.
# · Delivery Routing software (Global Positioning System) 1-3 years.
# · Proven customer service skills.
# · Knowledge of Metro New England area with the ability to read maps.
# · Must be able to work independently, make decisions, and resolve problems.
# · Must have knowledge of DOT/OSHA regulations.
# · Additional skills maybe required to perform additional task(s) specific to work location, department or line of business.
# · Must be able to jockey 26 Ft. box trucks in the depot yard.
#
# QUALIFICATIONS:
# · Current Driver License
# · High school diploma or equivalent.
# · Must successfully complete pre-employment testing / back ground / drug screening.
# · Must be able to read and speak the English language.
# · Must be able to work flexible schedules including weekends and holidays, and be available to address operational issues.
# NEHDS offers competitive compensation and comprehensive benefits package:
# · Health, Dental, life-insurance.
#
# Job Attributes
# compensation: 15.00 - $16.00 per hour
#
# employment type: full-time
#
#
# -----
# Job Title: TRUCK ROUTER
# Location: N/A
# Date: Oct  9
# Link: https://providence.craigslist.org/sof/d/swansea-truck-router/7211134439.html
# Job Description:
#
# QR Code Link to This Post
#
#
# ##########################################
# Please reply to this posting with your personal or company email AND phone number
# email: Clayton Cardoza        Email:  ccardoza @ nehds . com
# ##########################################
#
#
#
#
#
# Job Status: Full Time / 5 days / Evenings hours / Open Schedule availability / PM Hours: Monday / Tuesday / Wednesday / Friday 2pm-10pm AM Hours Saturday 7:00am – 3:30pm
# Industry: Transportation / Routing
#
#
# Essential Duties and Responsibilities
# Organizes and schedules all necessary resources required to accomplish activities. Coordinates daily operational needs with Leadership team.
# · Plans, distributes,monitors, and follows-up daily route assignments to ensure customers are serviced per Macys Furniture / NEHDS standards and agreements.
# · Monitors driver and laborer time and attendance, minimizing overtime and ensuring that drivers do not exceed limits established by regulatory agencies (e.g., 60 hour rule).
# · Reviews weekly demand/ volume for routes, determines potential gains from re-routing, and recommend-routes to the routing specialist.
# · Sets and monitors productivity, service, and safety targets for each route and driver.
# · Knowledge, Skills or Abilities Required Previous experience working in a routing capacity required.
# · Previous experience support delivery drivers 1-3 years.
# · Previous experience working in the transportation, logistics or home decor strongly preferred.
# · Flexible hours – able to work weekends
#
#
# REQUIREMENTS/SKILLS:
# · Excellent verbal and written communication skills.
# · Computer skills;working knowledge of Windows applications, Microsoft applications.
# · Delivery Routing software (Global Positioning System) 1-3 years.
# · Proven customer service skills.
# · Knowledge of Metro New England area with the ability to read maps.
# · Must be able to work independently, make decisions, and resolve problems.
# · Must have knowledge of DOT/OSHA regulations.
# · Additional skills maybe required to perform additional task(s) specific to work location, department or line of business.
# · Must be able to jockey 26 Ft. box trucks in the depot yard.
#
# QUALIFICATIONS:
# · Current Driver License
# · High school diploma or equivalent.
# · Must successfully complete pre-employment testing / back ground / drug screening.
# · Must be able to read and speak the English language.
# · Must be able to work flexible schedules including weekends and holidays, and be available to address operational issues.
# NEHDS offers competitive compensation and comprehensive benefits package:
# · Health, Dental, life-insurance.
#
# Job Attributes
# compensation: 15.00 - $16.00 per hour
#
# employment type: full-time
#
#
# -----
# Job Title: TRUCK ROUTER
# Location: N/A
# Date: Oct 25
# Link: https://southcoast.craigslist.org/sof/d/swansea-truck-router/7220185476.html
# Job Description:
#
# QR Code Link to This Post
#
#
# ##########################################
# Please reply to this posting with your personal or company email AND phone number
# email: Clayton Cardoza Email: ccardoza @ nehds . com
# ##########################################
#
#
#
#
#
# Job Status: Full Time / 5 days / Evenings hours / Open Schedule availability / PM Hours: Monday / Tuesday / Wednesday / Friday 2pm-10pm AM Hours Saturday 7:00am – 3:30pm
# Industry: Transportation / Routing
#
#
# Essential Duties and Responsibilities
# Organizes and schedules all necessary resources required to accomplish activities. Coordinates daily operational needs with Leadership team.
# · Plans, distributes,monitors, and follows-up daily route assignments to ensure customers are serviced per Macys Furniture / NEHDS standards and agreements.
# · Monitors driver and laborer time and attendance, minimizing overtime and ensuring that drivers do not exceed limits established by regulatory agencies (e.g., 60 hour rule).
# · Reviews weekly demand/ volume for routes, determines potential gains from re-routing, and recommend-routes to the routing specialist.
# · Sets and monitors productivity, service, and safety targets for each route and driver.
# · Knowledge, Skills or Abilities Required Previous experience working in a routing capacity required.
# · Previous experience support delivery drivers 1-3 years.
# · Previous experience working in the transportation, logistics or home decor strongly preferred.
# · Flexible hours – able to work weekends
#
#
# REQUIREMENTS/SKILLS:
# · Excellent verbal and written communication skills.
# · Computer skills;working knowledge of Windows applications, Microsoft applications.
# · Delivery Routing software (Global Positioning System) 1-3 years.
# · Proven customer service skills.
# · Knowledge of Metro New England area with the ability to read maps.
# · Must be able to work independently, make decisions, and resolve problems.
# · Must have knowledge of DOT/OSHA regulations.
# · Additional skills maybe required to perform additional task(s) specific to work location, department or line of business.
# · Must be able to jockey 26 Ft. box trucks in the depot yard.
#
# QUALIFICATIONS:
# · Current Driver License
# · High school diploma or equivalent.
# · Must successfully complete pre-employment testing / back ground / drug screening.
# · Must be able to read and speak the English language.
# · Must be able to work flexible schedules including weekends and holidays, and be available to address operational issues.
# NEHDS offers competitive compensation and comprehensive benefits package:
# · Health, Dental, life-insurance.
#
# Job Attributes
# compensation: 15.00 - $16.00 per hour
#
# employment type: full-time
#
#
# -----
# Job Title: Computer Programmer
# Location: N/A
# Date: Oct 15
# Link: https://capecod.craigslist.org/sof/d/woods-hole-computer-programmer/7214403468.html
# Job Description:
#
# QR Code Link to This Post
#
#
# Ocean Associates, Inc.
# Job Attributes
# compensation: Salary commensurate with experience. Excellent benefit package.
#
# employment type: full-time
#
#
# -----
# Job Title: Mobile App Development/Also PHP Backend Frontend work
# Location: N/A
# Date: Oct  3
# Link: https://newlondon.craigslist.org/sof/d/haddam-mobile-app-development-also-php/7207409821.html
# Job Description:
#
# QR Code Link to This Post
#
#
# Create an app for posting on my site that you can upload from Play Store and App Store
# Job Category
# Mobile App Development
#
# Description
# 1. Complete app for HiRunGo.com This app will post to HiRunGo.com, Facebook, Google Business with reviews through my site API. The app will log into all three platform profiles simultaneously. You can then post pictures, comments simultaneously.
# 2. Also, there will be a feature to send a link to customers to post a review for there project from there Google business short link for reviews.
# 3. Leave the app open for future expansion.
# https://demo.wowonder.com/api/v2/Documentation.html
#
# Details
#
# Type of Project
#
# One-time project
#
# What challenging part of this job are you most experienced in?
#
# Expertise
# App Features
# User AuthenticationReview or Feedback CollectionSocial Media Account IntegrationOfflineAPI Integration
#
# Google PlayApple App
#
# Experience Level
# Expert
#
# Work from home is fine.
# I also have PHP work to be done on my websites. Call 860-Eight Five3- o Four nine 3
# Job Attributes
# compensation: Contract or by the hour
#
# employment type: employee's choice
#
#
# -----
# Total Jobs: 37
